# %% [markdown]
# Given the `head` of a linked list, remove the **n<sup>th</sup>** node from the end of the list and return its head.
#
# <br>
#
# **Example 1:**
#
# ![remove_ex1.jpg](attachment:remove_ex1.jpg)
#
# >**Input:** head = [1,2,3,4,5], n = 2<br>
# >**Output:** [1,2,3,5]
#
#
# **Example 2:**
# >**Input:** head = [1], n = 1<br>
# >**Output:** []
#
#
# **Example 3:**
# >**Input:** head = [1,2], n = 1<br>
# >**Output:** [1]
#
# <br>
#
# **Constraints:**
# - >The number of nodes in the list is sz.
# - >1 <= sz <= 30
# - >0 <= Node.val <= 100
# - >1 <= n <= sz
#
# <br><br>
#
# **Follow up:** Could you do this in one pass?

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def removeNthFromEnd(self, head, n: int):
        if n == 0:
            return head
        
        fast = slow = head
        for _ in range(n):
            fast = fast.next
        
        if not fast:
            return head.next
        
        while fast.next:
            fast = fast.next
            slow = slow.next
        
        slow.next = slow.next.next
        
        return head
